# %%
import main

# %% [markdown]
# ### Sphere Collision Test
#
# This function samples points around a sphere and colors them based on whether they lie inside or outside the obstacle boundary.

# %%
main.run_sphere_collision_test(save_plot=True)

# %% [markdown]
# ### Potential-Based Planning for Two Goal Locations
#
# Runs the potential-based planner for the two goal locations in the sphere world and saves the resulting plots.

# %%
main.run_planner_test(save_plot=True)

# %% [markdown]
# ### 3D Potential Field Plot
#
# Builds a 3D visualization of the potential field over the workspace.

# %%
from main import plot_3d_potential

plot_3d_potential(save_plot=True)

# %% [markdown]
# ### Repulsive Fields for the First Two Spheres
#
# Visualizes the repulsive potential around the first two obstacles in the sphere world.

# %%
from main import plot_sphere_potential_fields

main.plot_sphere_potential_fields(save_plot=True)

# %% [markdown]
# ### CLF-CBF Control Field for a Single Sphere
#
# Creates the control-field visualization for the single-sphere CLF-CBF example.

# %%
from main import plot_clfcbf_control_singlesphere

plot_clfcbf_control_singlesphere(save_img=True)

# %%
from main import plot_sphere_world_control_field

plot_sphere_world_control_field(save_plot=True)

# %%
two_link_sphere_world(save_gif=True)
