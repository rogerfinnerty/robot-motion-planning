# %% [markdown]
# # Homework 1 Function Calls
# This notebook imports `main.py` and runs each test function defined in the file.
#
# Each code cell below calls one of the homework test functions so the output and plots are generated in order.

# %%
import main
print("Imported main.py and ready to call functions.")
# Out:
# Imported main.py and ready to call functions.

# %% [markdown]
# ## Edge Collision Test
#
# Creates one edge from from [0;0] to [1,1] and a second random edge with endpoints contained in the square [0,1] [0,1], and plots them in green if they do not overlap, and in red otherwise.

# %%
main.edge_is_collision_test(save_fig=True)

# %% [markdown]
# ## Polygon Self-Occlusion Test
#
# Picks a random arrangement of 3 vertices and then systematically tests a set of points for occlusion with the polygon. Green lines indicate non-occlusions
#
# In our formulation, a polygon with clockwise vertex ordering is considered hollow, meaning the space outside the vertices is occupied by the polygon. For counter-clockwise vertices, the polygon is filled in.

# %%
nb_points = 50
main.polygon_is_self_occluded_test(nb_points, save_fig=True)

# %% [markdown]
# ## Polygon Point Visibility Test
#
# This function tests for visibility relative to the polygons of the two-link manipulator system, for both hollow and solid variants. In each case, a test point is plotted in the polygon, and lines are drawn between all the vertices of the polygon, and connecting the vertices and the test point. A green line indicates visibility, a red line indicates occlusion.

# %%
main.polygon_is_visible_test(save_fig=True)

# %% [markdown]
# ## Polygon Collision Test
# For hollow and solid versions of both polygons in the two-link manipulator, this function tests many points for collision. Red points are in collision, green ones are not.

# %%
main.polygon_is_collision_test(save_fig=True)
