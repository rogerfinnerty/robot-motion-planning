# %%
import main

# %% [markdown]
# ### XY-Plane Rotation in 3D
#
# Rotate a line in the XY plane in 3D space by a given angle `theta`.

# %%
import math

theta = math.pi/4
main.rotation_3d(theta, save_plot=True)
# Out:
# [[-0.70710678]
#  [-0.70710678]
#  [ 0.        ]]

# %% [markdown]
# ### Plot Torus
#
# Plots a torus in 3D space. Also plots the 3D embeddings from four curves defined by:
#
# ```python
# [3/4*pi, 0]
# [3/4*pi, 3/4*pi]
# [-3/4*pi, 3/4*pi]
# [0 -3/4*pi]
# b=np.array([[-1],[-1]]).
# ```

# %%
main.plot_torus(save_plot=True)

# %% [markdown]
# ### Two-Link Manipulator Collision Test
#
# This function loads the test points defined in `twolink_testData.mat`, plots the two link manipulator at a random angle, and checks whether it is in collision with any of the points.

# %%
import numpy as np
main.two_link_collision(theta, save_plot=True)

# %% [markdown]
# ### Two-Link Orientations and End Effector Velocity
# For four orientations ($\theta_1$, $\theta_2$), and two angular velocities ($\dot\theta_1$, $\dot\theta_2$), this function plots the two-link manipulator and the velocity vector of the end effector.

# %%
main.end_effector_velocity(save_animation=True)
# Out:
# Saved animation to assets/end_effector_velocity.gif

# %% [markdown]
# ### Move Two-Link Manipulator
#
# This function plots the positions of the two-link manipulators using the curves defined in `main.plot_torus`, as well as the velocity vector of the end-effector. The `animate=True` arg saves a GIF for each of the four curves.

# %%
main.torus_twolink_plot_jacobian(animate=True)
